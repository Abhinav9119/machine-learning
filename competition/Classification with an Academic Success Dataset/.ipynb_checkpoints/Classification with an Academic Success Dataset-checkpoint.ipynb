# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
import warnings
warnings.simplefilter("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

# %%
train=pd.read_csv("train.csv",index_col=0)

# %%
train.head()
# Out:
#     Marital status  Application mode  Application order  Course  \
# id
# 0                1                 1                  1    9238
# 1                1                17                  1    9238
# 2                1                17                  2    9254
# 3                1                 1                  3    9500
# 4                1                 1                  2    9500
#
#     Daytime/evening attendance  Previous qualification  \
# id
# 0                            1                       1
# 1                            1                       1
# 2                            1                       1
# 3                            1                       1
# 4                            1                       1
#
#     Previous qualification (grade)  Nacionality  Mother's qualification  \
# id
# 0                            126.0            1                       1
# 1                            125.0            1                      19
# ...

# %%
#converting categorica columns into object which are look like object
#train["Marital status"]=train["Marital status"].astype(object)

#preprocessing on train set
train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]]=train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]].astype(object)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76518 entries, 0 to 76517
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  76518 non-null  object
#  1   Application mode                                76518 non-null  object
#  2   Application order                               76518 non-null  object
#  3   Course                                          76518 non-null  object
#  4   Daytime/evening attendance                      76518 non-null  int64
#  5   Previous qualification                          76518 non-null  object
#  6   Previous qualification (grade)                  76518 non-null  float64
#  7   Nacionality                                     76518 non-null  object
#  8   Mother's qualification                          76518 non-null  object
# ...

# %%
le =LabelEncoder()
train['Target'] = le.fit_transform(train['Target'])
dum_trn = pd.get_dummies(train,drop_first=True)
y = train['Target']
x = train.drop('Target', axis=1)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,stratify=y,random_state=24)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
params = {'penalty':['l2',None], 'C':np.linspace(0.001, 10,20),'solver':['lbfgs','newton-cg','newton-cholesky','sag'],'multi_class':['ovr','multinomial']}


lr = LogisticRegression()
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
rgcv_r= RandomizedSearchCV(lr,param_distributions=params,scoring="accuracy",cv=kfold,n_iter=5,verbose=3)
rgcv_r.fit(x,y)

print(rgcv_r.best_params_)
print(rgcv_r.best_score_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END C=6.84242105263158, multi_class=ovr, penalty=None, solver=lbfgs;, score=0.815 total time=   8.9s
# [CV 2/5] END C=6.84242105263158, multi_class=ovr, penalty=None, solver=lbfgs;, score=0.809 total time=   8.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 9
#       7 kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
#       8 rgcv_r= RandomizedSearchCV(lr,param_distributions=params,scoring="accuracy",cv=kfold,n_iter=5,verbose=3)
# ----> 9 rgcv_r.fit(x,y)
#      11 print(rgcv_r.best_params_)
#      12 print(rgcv_r.best_score_)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
# ...

# %%
mm_scaler=MinMaxScaler()
knn=KNeighborsClassifier()
pipe=Pipeline([("SCL",mm_scaler),("KNN",knn)])
params={"KNN__n_neighbors":np.arange(1,16)}
kfole=StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,verbose=3,scoring="neg_log_loss")
gcv.fit(x,y)
print(gcv.best_params_)
print(gcv.best_score_)

# %%
best_model=gcv.best_estimator_
test=pd.read_csv("test.csv")

#preprocessing on test set
train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]]=train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]].astype(object)

# %%
dum_tst = pd.get_dummies(train,drop_first=True)
prediction=best_model.predict(dum_tst) #error : Feature names unseen at fit time:
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 2
#       1 dum_tst = pd.get_dummies(train,drop_first=True)
# ----> 2 prediction=best_model.predict(dum_tst)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:603, in Pipeline.predict(self, X, **params)
#     601 if not _routing_enabled():
#     602     for _, name, transform in self._iter(with_final=False):
# --> 603         Xt = transform.transform(Xt)
#     604     return self.steps[-1][1].predict(Xt, **params)
#     606 # metadata routing enabled
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.compose import make_column_selector

# %%
ohc = OneHotEncoder(sparse_output=False, drop='first',handle_unknown="ignore").set_output(transform='pandas')
ct = make_column_transformer((ohc,make_column_selector(dtype_include=object)),("passthrough",make_column_selector(dtype_exclude=object)),verbose_feature_names_out=False)
x_tran=ct.fit_transform(x)

ct=ct.set_output(transform="pandas")
x_trans=ct.fit_transform(x)
print(x_trans.columns)
#
lr = LogisticRegression()
# kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
# rgcv_r= RandomizedSearchCV(lr,param_distributions=params,scoring="accuracy",cv=kfold,n_iter=5,verbose=3)
lr.fit(x_trans,y)
# Out:
# Index(['Marital status_2', 'Marital status_3', 'Marital status_4',
#        'Marital status_5', 'Marital status_6', 'Application mode_2',
#        'Application mode_3', 'Application mode_4', 'Application mode_5',
#        'Application mode_7',
#        ...
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
#        'Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
#        'Inflation rate', 'GDP'],
#       dtype='object', length=280)

# %%
 tst=pd.read_csv("test.csv")
train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]]=train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]].astype(object)
tst_trans=ct.transform(tst)
print(tst_trans.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 tst=pd.read_csv("test.csv")
#       2 train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]]=train[["Marital status","Application mode","Application order","Previous qualification","Nacionality","Mother's qualification","Father's qualification","Mother's occupation","Father's occupation","Course"]].astype(object)
# ----> 3 tst_trans=ct.transform(tst)
#       4 print(tst_trans.columns)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# ...

# %%
import pandas as pd 
import numpy as np 
import os 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.compose import make_column_transformer,make_column_selector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
# os.chdir(r"C:\Training\Kaggle\Competitions\Playground Competitions\Academic Success")

train = pd.read_csv("train.csv", index_col=0)

train['Marital status'] = train['Marital status'].astype(object)
train['Application mode'] = train['Application mode'].astype(object)
train['Application order'] = train['Application order'].astype(object)
train['Previous qualification'] = train['Previous qualification'].astype(object)
train['Nacionality'] = train['Nacionality'].astype(object)
train["Mother's qualification"] = train["Mother's qualification"].astype(object)
train["Father's qualification"] = train["Father's qualification"].astype(object)
train["Mother's occupation"] = train["Mother's occupation"].astype(object)
train["Father's occupation"] = train["Father's occupation"].astype(object)
train['Course'] = train['Course'].astype(object)

le = LabelEncoder()
train['Target'] = le.fit_transform(train['Target'])

y = train['Target']
X = train.drop('Target', axis=1)

# mm_scaler = MinMaxScaler()
# knn = KNeighborsClassifier()
# pipe = Pipeline([('SCL', mm_scaler),('KNN', knn)])
# params = {'KNN__n_neighbors':np.arange(1, 16) }
# kfold = StratifiedKFold(n_splits=5, 
#                         shuffle=True, random_state=24)
# gcv = GridSearchCV(pipe, param_grid=params, cv=kfold,verbose=3,
#                    scoring='neg_log_loss')
# gcv.fit(X, y)
# print(gcv.best_params_)
# print(gcv.best_score_)

#### Column Transformer on Train set
ohc = OneHotEncoder(sparse_output=False,
      handle_unknown='ignore', 
      drop='first').set_output(transform='pandas')
ct = make_column_transformer((ohc,
     make_column_selector(dtype_include=object) ),
       ("passthrough",
     make_column_selector(dtype_exclude=object) ),
      verbose_feature_names_out = False)
X_tran = ct.fit_transform(X)
lr = LogisticRegression()
lr.fit(X_tran, y)

#best_model = gcv.best_estimator_

test = pd.read_csv("test.csv", index_col=0)

test['Marital status'] = test['Marital status'].astype(object)
test['Application mode'] = test['Application mode'].astype(object)
test['Application order'] = test['Application order'].astype(object)
test['Previous qualification'] = test['Previous qualification'].astype(object)
test['Nacionality'] = test['Nacionality'].astype(object)
test["Mother's qualification"] = test["Mother's qualification"].astype(object)
test["Father's qualification"] = test["Father's qualification"].astype(object)
test["Mother's occupation"] = test["Mother's occupation"].astype(object)
test["Father's occupation"] = test["Father's occupation"].astype(object)
test['Course'] = test['Course'].astype(object)


dum_tst = ct.transform(test)
prediction = lr.predict(dum_tst)

# %%
prediction
# Out:
# array([0, 2, 2, ..., 0, 1, 0])

# %%
prediction=le.inverse_transform(prediction)

# %%
prediction
# Out:
# array(['Dropout', 'Graduate', 'Graduate', ..., 'Dropout', 'Enrolled',
#        'Dropout'], dtype=object)

# %%
submit=pd.DataFrame({"id":list(test.index),"Target":prediction})

# %%
submit.to_csv("submission.csv",index=False)

# %%
import pandas as pd 
import numpy as np 
import os 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.compose import make_column_transformer,make_column_selector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
#os.chdir(r"C:\Training\Kaggle\Competitions\Playground Competitions\Academic Success")

train = pd.read_csv("train.csv", index_col=0)

train['Marital status'] = train['Marital status'].astype(object)
train['Application mode'] = train['Application mode'].astype(object)
train['Application order'] = train['Application order'].astype(object)
train['Previous qualification'] = train['Previous qualification'].astype(object)
train['Nacionality'] = train['Nacionality'].astype(object)
train["Mother's qualification"] = train["Mother's qualification"].astype(object)
train["Father's qualification"] = train["Father's qualification"].astype(object)
train["Mother's occupation"] = train["Mother's occupation"].astype(object)
train["Father's occupation"] = train["Father's occupation"].astype(object)
train['Course'] = train['Course'].astype(object)

le = LabelEncoder()
train['Target'] = le.fit_transform(train['Target'])

y = train['Target']
X = train.drop('Target', axis=1)

#### Column Transformer on Train set
ohc = OneHotEncoder(sparse_output=False,
      handle_unknown='ignore', 
      drop='first').set_output(transform='pandas')
ct = make_column_transformer((ohc,
     make_column_selector(dtype_include=object) ),
       ("passthrough",
     make_column_selector(dtype_exclude=object) ),
      verbose_feature_names_out = False)
X_tran = ct.fit_transform(X)
lr = LogisticRegression()
lr.fit(X_tran, y)


mm_scaler = MinMaxScaler()
knn = KNeighborsClassifier()
pipe = Pipeline([("TRNS",ct),('SCL', mm_scaler),('KNN', knn)])
params = {'KNN__n_neighbors':np.arange(1, 13) }
kfold = StratifiedKFold(n_splits=5, 
                        shuffle=True, random_state=24)
gcv = GridSearchCV(pipe, param_grid=params, cv=kfold,verbose=3,
                   scoring='accuracy')
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)

#### Column Transformer on Train set
# ohc = OneHotEncoder(sparse_output=False,
#       handle_unknown='ignore', 
#       drop='first').set_output(transform='pandas')
# ct = make_column_transformer((ohc,
#      make_column_selector(dtype_include=object) ),
#        ("passthrough",
#      make_column_selector(dtype_exclude=object) ),
#       verbose_feature_names_out = False)
# X_tran = ct.fit_transform(X)
# lr = LogisticRegression()
# lr.fit(X_tran, y)

#best_model = gcv.best_estimator_

test = pd.read_csv("test.csv", index_col=0)

test['Marital status'] = test['Marital status'].astype(object)
test['Application mode'] = test['Application mode'].astype(object)
test['Application order'] = test['Application order'].astype(object)
test['Previous qualification'] = test['Previous qualification'].astype(object)
test['Nacionality'] = test['Nacionality'].astype(object)
test["Mother's qualification"] = test["Mother's qualification"].astype(object)
test["Father's qualification"] = test["Father's qualification"].astype(object)
test["Mother's occupation"] = test["Mother's occupation"].astype(object)
test["Father's occupation"] = test["Father's occupation"].astype(object)
test['Course'] = test['Course'].astype(object)


dum_tst = ct.transform(test)
prediction = lr.predict(dum_tst)
